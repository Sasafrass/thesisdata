# %% [markdown]
# # Inspection of dataset that wasn't used

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('PTSD_VandeSchoot_18.csv', encoding = "unicode_escape")

# %%
len(df)
# Out:
# 5780

# %%
len(df[df['included'] == 1])
# Out:
# 38

# %%
df.head()
# Out:
#                                              authors  \
# 0                  Achenbach, T. M., Rescorla, L. A.
# 1                  Dallow, N., Lang, J., Bellamy, N.
# 2  Ford, J. D., Grasso, D. J., Elhai, J. D., Cour...
# 3                Hollingshead, A. B., Redlich, F. C.
# 4                                      Irvine, S. H.
#
#                                                title keywords  \
# 0       Manual for ASEBA School-Age Forms & Profiles      NaN
# 1  Queensland Trauma Registry: A summary of paedi...      NaN
# 2  Posttraumatic Stress Disorder: Scientific and ...      NaN
# 3                    SOCIAL CLASS AND MENTAL ILLNESS      NaN
# 4  Computerised test generation for cross-nationa...      NaN
#
#                                             abstract  included
# 0                                                NaN         0
# 1                                                NaN         0
# 2  This comprehensive overview of research and cl...         0
# ...

# %%
included = df[df['included'] == 1]

# %%
included
# Out:
#                                                 authors  \
# 273   Andersen, S. B., Karstoft, K. I., Bertelsen, M...
# 321    Armour, C., Shevlin, M., Elklit, A., Mroczek, D.
# 559   Berntsen, D., Johannessen, K. B., Thomsen, Y. ...
# 638   Boasso, A. M., Steenkamp, M. M., Nash, W. P., ...
# 680   Bonanno, George A., Mancini, Anthony D., Horto...
# 850   Bryant, R. A., Nickerson, A., Creamer, M., "OD...
# 1344  deRoon-Cassini, T. A., Mancini, A. D., Rusch, ...
# 1363  Dickstein, B. D., Suvak, M., Litz, B. T., Adle...
# 1478  Eekhout, I., Reijnen, A., Vermetten, E., Geuze...
# 1816  Galatzer-Levy, I. R., Ankri, Y., Freedman, S.,...
# 1826  Galatzer-Levy, I. R., Madan, A., Neylan, T. C....
# 2254  Hiller, R. M., Halligan, S. L., Ariyanayagam, ...
# 2280  Hobfoll, S. E., Mancini, A. D., Hall, B. J., C...
# 2314  Holgersen, K. H., Klockner, C. A., Boe, H. J.,...
# 2323  Hong, S. B., Youssef, G. J., Song, S. H., Choi...
# 2339         Hou, W. K., Law, C. C., Yin, J., Fu, Y. T.
# ...
